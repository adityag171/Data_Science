# ...

# %%
response.json()
# Out:
# {'success': True,
#  'timestamp': 1623320644,
#  'base': 'EUR',
#  'date': '2021-06-10',
#  'rates': {'AED': 4.468001,
#   'AFN': 96.036807,
#   'ALL': 122.999065,
#   'AMD': 632.030313,
#   'ANG': 2.187061,
#   'AOA': 780.960823,
#   'ARS': 115.620127,
#   'AUD': 1.571752,
#   'AWG': 2.189609,
#   'AZN': 2.078664,
#   'BAM': 1.951338,
#   'BBD': 2.460081,
#   'BDT': 103.145844,
#   'BGN': 1.955108,
#   'BHD': 0.458568,
#   'BIF': 2409.495484,
#   'BMD': 1.21645,
#   'BND': 1.612273,
#   'BOB': 8.399363,
#   'BRL': 6.159124,
#   'BSD': 1.218398,
#   'BTC': 3.1766022e-05,
#   'BTN': 88.748389,
#   'BWP': 12.866134,
#   'BYN': 3.042098,
#   'BYR': 23842.411392,
#   'BZD': 2.455984,
#   'CAD': 1.472938,
#   'CDF': 2426.816753,
#   'CHF': 1.090057,
#   'CLF': 0.031737,
#   'CLP': 875.722475,
#   'CNY': 7.77603,
#   'COP': 4365.752322,
#   'CRC': 754.293665,
#   'CUC': 1.21645,
#   'CUP': 32.235913,
#   'CVE': 110.219619,
#   'CZK': 25.408587,
#   'DJF': 216.907272,
#   'DKK': 7.436643,
# ...

# %%
type(response.json())
# Out:
# dict

# %%
import json

# %%
json.dumps(response.json(), indent = 4)
# Out:
# '{\n    "success": true,\n    "timestamp": 1623320644,\n    "base": "EUR",\n    "date": "2021-06-10",\n    "rates": {\n        "AED": 4.468001,\n        "AFN": 96.036807,\n        "ALL": 122.999065,\n        "AMD": 632.030313,\n        "ANG": 2.187061,\n        "AOA": 780.960823,\n        "ARS": 115.620127,\n        "AUD": 1.571752,\n        "AWG": 2.189609,\n        "AZN": 2.078664,\n        "BAM": 1.951338,\n        "BBD": 2.460081,\n        "BDT": 103.145844,\n        "BGN": 1.955108,\n        "BHD": 0.458568,\n        "BIF": 2409.495484,\n        "BMD": 1.21645,\n        "BND": 1.612273,\n        "BOB": 8.399363,\n        "BRL": 6.159124,\n        "BSD": 1.218398,\n        "BTC": 3.1766022e-05,\n        "BTN": 88.748389,\n        "BWP": 12.866134,\n        "BYN": 3.042098,\n        "BYR": 23842.411392,\n        "BZD": 2.455984,\n        "CAD": 1.472938,\n        "CDF": 2426.816753,\n        "CHF": 1.090057,\n        "CLF": 0.031737,\n        "CLP": 875.722475,\n        "CNY": 7.7
# ...

# %%
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "success": true,
#     "timestamp": 1623320644,
#     "base": "EUR",
#     "date": "2021-06-10",
#     "rates": {
#         "AED": 4.468001,
#         "AFN": 96.036807,
#         "ALL": 122.999065,
#         "AMD": 632.030313,
#         "ANG": 2.187061,
#         "AOA": 780.960823,
#         "ARS": 115.620127,
#         "AUD": 1.571752,
#         "AWG": 2.189609,
#         "AZN": 2.078664,
#         "BAM": 1.951338,
#         "BBD": 2.460081,
#         "BDT": 103.145844,
#         "BGN": 1.955108,
#         "BHD": 0.458568,
#         "BIF": 2409.495484,
#         "BMD": 1.21645,
#         "BND": 1.612273,
#         "BOB": 8.399363,
#         "BRL": 6.159124,
#         "BSD": 1.218398,
#         "BTC": 3.1766022e-05,
#         "BTN": 88.748389,
#         "BWP": 12.866134,
#         "BYN": 3.042098,
#         "BYR": 23842.411392,
#         "BZD": 2.455984,
#         "CAD": 1.472938,
#         "CDF": 2426.816753,
#         "CHF": 1.090057,
#         "CLF": 0.031737,
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['success', 'timestamp', 'base', 'date', 'rates'])

# %%
param_url = base_url + "&symbols=USD,GBP"
param_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=758953db0b8a9afd1ed2aa16623c5531&symbols=USD,GBP'

# %%
response = requests.get(param_url)
response.ok
# Out:
# True

# %%
data = response.json()

# %%
data
# Out:
# {'success': True,
#  'timestamp': 1623320644,
#  'base': 'EUR',
#  'date': '2021-06-10',
#  'rates': {'USD': 1.21645, 'GBP': 0.86301}}

# %%
data['base']
# Out:
# 'EUR'

# %%
data['date']
# Out:
# '2021-06-10'

# %%
data['rates']
# Out:
# {'USD': 1.21645, 'GBP': 0.86301}

# %%
param_url = base_url + "&symbols=GBP" + "&base=EUR"
param_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=758953db0b8a9afd1ed2aa16623c5531&symbols=GBP&base=EUR'

# %%
data = requests.get(param_url).json()
data
# Out:
# {'success': True,
#  'timestamp': 1623320644,
#  'base': 'EUR',
#  'date': '2021-06-10',
#  'rates': {'GBP': 0.86301}}

# %%
eur_to_gbp = data['rates']['GBP']
eur_to_gbp
# Out:
# 0.86301

# %%
his_url = base_url + "/2016-01-01"
his_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=758953db0b8a9afd1ed2aa16623c5531/2016-01-01'

# %%
response = requests.get(his_url)
response.status_code
# Out:
# 401

# %%
base_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=758953db0b8a9afd1ed2aa16623c5531'
